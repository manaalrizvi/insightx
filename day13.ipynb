# %%
import numpy as np
from scipy import stats
advertisingcost = np.array([100, 200, 300, 400, 500])
sales= np.array([20, 25, 40, 50, 65])
correlation, p_value = stats.pearsonr(advertising_cost, sales)

print("Correlation:", correlation)
print("P-value:", p_value)
# Out:
# Correlation: 0.9897624106974507
# P-value: 0.001241544723329606
